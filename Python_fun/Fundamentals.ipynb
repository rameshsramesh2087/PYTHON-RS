# %% [markdown]
# PYTHON COMMENT
#
# python comments explain python codes. comment can make the code more redable.
# creating a comment, comment start with a # python will ignore them.

# %%
#python comment
print("HELLO WORLD")
# Out:
# HELLO WORLD

# %% [markdown]
# MUILTI LINE COMMENT
#
# python does not have a multiline comments. but multiline string using comment can be used a python comment.

# %%
''' Multiline comment
in python
'''
# Out:
# ' Multiline comment\nin python\n'

# %%
''' Multiline comment
in python
'''
print("hello world")
# Out:
# hello world
